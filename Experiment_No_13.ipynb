# %% [markdown]
# Experiment No.13
#
# Name : Pranav Menon\
# Batch : ENTC - B1\
# PRN No. : 25070123085
#
# Aim : To perform preprocessing on a datset and Dealing with Missing Values

# %%
# Create a Dataset
import pandas as pd
import numpy as np
df1 = pd.DataFrame({'c1':[11,21,np.nan],'c2':[15,np.nan,np.nan],'c3':[10,20,30]})
df1
# Out:
#      c1    c2  c3
# 0  11.0  15.0  10
# 1  21.0   NaN  20
# 2   NaN   NaN  30

# %%
# To determine Null Values
df1.isna()
# Out:
#       c1     c2     c3
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
# Operations on Dataset
df1.notna()
# Out:
#       c1     c2    c3
# 0   True   True  True
# 1   True  False  True
# 2  False  False  True

# %%
# Operations on Dataset
df1.isna().sum()
# Out:
# c1    1
# c2    2
# c3    0
# dtype: int64

# %%
# Operations on Dataset
df1.isna().sum(axis=1)
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
# Operations on Dataset
df1.dropna()
# Out:
#      c1    c2  c3
# 0  11.0  15.0  10

# %%
# Operations on Dataset
df1.dropna(axis=1)
# Out:
#    c3
# 0  10
# 1  20
# 2  30

# %%
# Operations on Dataset
df1.fillna(0)
# Out:
#      c1    c2  c3
# 0  11.0  15.0  10
# 1  21.0   0.0  20
# 2   0.0   0.0  30

# %%
# Operations on Dataset
df1.fillna(df1.mean())
# Out:
#      c1    c2  c3
# 0  11.0  15.0  10
# 1  21.0  15.0  20
# 2  16.0  15.0  30

# %%
# Row Mean and fill
df1.fillna(df1.mean(axis=1))
# Out:
#      c1    c2  c3
# 0  11.0  15.0  10
# 1  21.0   NaN  20
# 2   NaN   NaN  30

# %%
# Preprocessing on a Dataset
import pandas as pd
data = {
    "Roll No": [101, 102, 103, 104, 105],
    "Name": ["Asha", "Rohan", "Meera", "Karan", "Anil"],
    "Age": [20, "-", 21, 20, "22"],
    "Marks": [85, 90, "-", 88, 76],
    "Department": ["CSE", "IT", "CSE", "cse", "E&TC"],
    "Admission_Date": ["01-06-2023", "03-06-2023", "05-06-2023", "07-06-2023", "10/06/23"]
}
df = pd.DataFrame(data)
df
# Out:
#    Roll No   Name Age Marks Department Admission_Date
# 0      101   Asha  20    85        CSE     01-06-2023
# 1      102  Rohan   -    90         IT     03-06-2023
# 2      103  Meera  21     -        CSE     05-06-2023
# 3      104  Karan  20    88        cse     07-06-2023
# 4      105   Anil  22    76       E&TC       10/06/23

# %%
# Operations on Dataset
df.replace("-",np.nan,inplace = True)
df
# Out:
# /tmp/ipykernel_4130/560965395.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace("-",np.nan,inplace = True)
#    Roll No   Name  Age  Marks Department Admission_Date
# 0      101   Asha   20   85.0        CSE     01-06-2023
# 1      102  Rohan  NaN   90.0         IT     03-06-2023
# 2      103  Meera   21    NaN        CSE     05-06-2023
# 3      104  Karan   20   88.0        cse     07-06-2023
# 4      105   Anil   22   76.0       E&TC       10/06/23

# %%
# Convert Columns to Numeric Wherever required
df["Age"] = pd.to_numeric(df["Age"], errors='coerce')
df["Marks"] = pd.to_numeric(df["Marks"], errors='coerce')
df
# Out:
#    Roll No   Name   Age  Marks Department Admission_Date
# 0      101   Asha  20.0   85.0        CSE     01-06-2023
# 1      102  Rohan   NaN   90.0         IT     03-06-2023
# 2      103  Meera  21.0    NaN        CSE     05-06-2023
# 3      104  Karan  20.0   88.0        cse     07-06-2023
# 4      105   Anil  22.0   76.0       E&TC       10/06/23

# %%
# Check missing value
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Roll No           0
# Name              0
# Age               1
# Marks             1
# Department        0
# Admission_Date    0
# dtype: int64

# %%
df["Age"].fillna(df["Age"].mean(), inplace=True)
df["Marks"].fillna(df["Marks"].median(), inplace=True)
df
# Out:
# /tmp/ipykernel_4130/3758891222.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(), inplace=True)
# /tmp/ipykernel_4130/3758891222.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Operations on Dataset
df["Department"] = df["Department"].str.upper()
df
# Out:
#    Roll No   Name    Age  Marks Department Admission_Date
# 0      101   Asha  20.00   85.0        CSE     01-06-2023
# 1      102  Rohan  20.75   90.0         IT     03-06-2023
# 2      103  Meera  21.00   86.5        CSE     05-06-2023
# 3      104  Karan  20.00   88.0        CSE     07-06-2023
# 4      105   Anil  22.00   76.0       E&TC       10/06/23

# %%
# Convert admission date to standard Date
df["Admission_Date"] = pd.to_datetime(df["Admission_Date"] ,format="mixed" , dayfirst = True, errors= 'coerce')
df
# Out:
#    Roll No   Name    Age  Marks Department Admission_Date
# 0      101   Asha  20.00   85.0        CSE     2023-06-01
# 1      102  Rohan  20.75   90.0         IT     2023-06-03
# 2      103  Meera  21.00   86.5        CSE     2023-06-05
# 3      104  Karan  20.00   88.0        CSE     2023-06-07
# 4      105   Anil  22.00   76.0       E&TC     2023-06-10
